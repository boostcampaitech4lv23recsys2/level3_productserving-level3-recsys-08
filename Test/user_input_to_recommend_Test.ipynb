# %%
import os
import sys
sys.path.append('..')
from Utils import user_input_to_recommend

# %%
prefer_movie_ids =  [1704, 1721, 2021, 72998, 73141, 91500, 164909]
mbti="INTJ"
engram="3w2"
result = user_input_to_recommend(mbti, engram, prefer_movie_ids, top_k=10)
result
# Out:
#                      Character                              Contents  MBTI  \
# 5377              Felonius Gru             Despicable Me (Franchise)  INTJ
# 5407                  Christof                The Truman Show (1998)  INTJ
# 5417  Robert Callaghan "Yokai"                     Big Hero 6 (2014)  INTJ
# 5983                 John Reid              Bohemian Rhapsody (2018)  INTJ
# 5734                      TRON                         Tron (Series)  INTJ
# 5400                    Elrond  The Lord of the Rings (Film Trilogy)  INTJ
# 5935                   Agent O                          Men in Black  INTJ
# 5482                  Ben Cash              Captain Fantastic (2016)  INTJ
# 5834         Dr. Arthur Neuman                       The Mask (1994)  INTJ
# 5491                Paul Finch                          American Pie  INTJ
#
#      Enneagram                                            img_src   movieId  \
# ...

# %%
cols=['Character','Contents','MBTI','img_src']
result[cols].to_dict(orient='records')
# Out:
# [{'Character': 'Felonius Gru',
#   'Contents': 'Despicable Me (Franchise)',
#   'MBTI': 'INTJ',
#   'img_src': 'https://static1.personality-database.com/profile_images/f91fdbe3a72145c68cc0933fd66e5e65.png'},
#  {'Character': 'Christof',
#   'Contents': 'The Truman Show (1998)',
#   'MBTI': 'INTJ',
#   'img_src': 'https://static1.personality-database.com/profile_images/5d29da97f7284feb83c4b71d8cc9c8a8.png'},
#  {'Character': 'Robert Callaghan "Yokai"',
#   'Contents': 'Big Hero 6 (2014)',
#   'MBTI': 'INTJ',
#   'img_src': 'https://static1.personality-database.com/profile_images/a591bb9cc64d4a49baf5d052ccbc75fc.png'},
#  {'Character': 'John Reid',
#   'Contents': 'Bohemian Rhapsody (2018)',
#   'MBTI': 'INTJ',
#   'img_src': 'https://static1.personality-database.com/profile_images/51a7135ed3ad4b02887b5605f56acd05.png'},
#  {'Character': 'TRON',
#   'Contents': 'Tron (Series)',
#   'MBTI': 'INTJ',
# ...
